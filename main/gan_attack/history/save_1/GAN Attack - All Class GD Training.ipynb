# %% [markdown]
# # Attack attempt, training both G and D in the GAN, using all classes to train the G

# %% [markdown]
# First attempt at training the GAN D/G to provide **valid** and **representable** data from unknown classes

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
# tf.enable_eager_execution() # default for TF 2.0

tf.keras.backend.clear_session()  # For easy reset of notebook state.
from tensorflow import keras  # Import the tf version of keras.
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, \
                                    LeakyReLU, Conv2DTranspose, Reshape
# import keras.backend as K
from tensorflow.keras.datasets import mnist

print('TF', tf.__version__)
print('Keras', keras.__version__)
# Out:
# TF 2.1.0
# Keras 2.2.4-tf

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook, tqdm
import pickle
from glob import glob

import os.path
import shutil
import math
import random
from copy import copy

# %%
# Setting seeds for reproducibility 
np.random.seed(0)
tf.random.set_seed(0)

# Enlargen plots
plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# ## Parameters

# %%
# EASY_MODE: if True, Split Learning NN is used as the Discriminator in the GAN. This is good for testing, but
# bypasses the black-box paradigm! Use with caution
EASY_MODE = True

# Black-box params (optimized for MNIST)
best_depth = 9
best_filters = 33
best_dense = 110

# GAN params
gan_epochs = 150 # 25
gan_batch_size = 256 # 60
noise_dim = 100

# Split Learning params
clients_per_class = 100                         # number of clients per label. Each client only has access to one label
                                                # - each unique class is divided into X number of subsets

# split_batch_size = 256                          # number of clients to train on at once
split_minibatch_size = None                     # number of samples to operate on at one time
                                                # - can vary to optimize computing requirements
                                                # - if None, will evaluate the client's whole batch regardless of its size
    
split_batches_per_train_step = 20               # after averaging the gradients from X clients, we will apply them to the model
split_epochs = 25
shuffle_clients = True
split_num_classes = 10
split_eval_batch_size = 256 # 60

# dataset params
separated_folder = "./separated_dataset"
os.makedirs(separated_folder, exist_ok=True)
separated_train_path = os.path.join(separated_folder, "train_separated.pkl")
separated_test_path = os.path.join(separated_folder, "test_separated.pkl")

# input image dimensions
img_rows, img_cols = 28, 28
target_rows, target_cols = 28, 28    # governed by the chosen model
input_shape = (target_rows, target_cols, 1)

# %%
# setup checkpoint folders
blackbox_checkpoint_folder = "blackbox_checkpoint"
discriminator_checkpoint_folder = "discriminator_checkpoint"
generator_checkpoint_folder = "generator_checkpoint"

# %% [markdown]
# ## Load Data

# %%
# The data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if keras.backend.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = (x_train - 127.5) / 127.5 # Normalize the images to [-1, 1]
# x_train /= 255    # range is [0, 1]
x_test = (x_test - 127.5) / 127.5 # Normalize the images to [-1, 1]
# x_test /= 255     # range is [0, 1]

if target_rows != img_rows or target_cols != img_cols:
    # resize x_train
    x_train_resized = []
    for x_ in x_train:
        # scale image to be the same WxH as we need:
        x_ = cv2.resize(x_, dsize=(target_rows, target_cols), interpolation=cv2.INTER_CUBIC)
        x_train_resized.append(x_)
    x_train = np.asarray(x_train_resized)

    # resize x_test
    x_test_resized = []
    for x_ in x_test:
        # scale image to be the same WxH as we need:
        x_ = cv2.resize(x_, dsize=(target_rows, target_cols), interpolation=cv2.INTER_CUBIC)
        x_test_resized.append(x_)
    x_test = np.asarray(x_test_resized)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, split_num_classes)
y_test = keras.utils.to_categorical(y_test, split_num_classes)

# %%
# summary of data shapes:
print('X:', x_train.shape, x_test.shape)
print('y:', y_train.shape, y_test.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

BUFFER_SIZE = x_train.shape[0]
# Out:
# X: (60000, 28, 28, 1) (10000, 28, 28, 1)
# y: (60000, 10) (10000, 10)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# #### Separate the data by class

# %%
# Separating the data by class
if os.path.isfile(separated_train_path):
    with open(separated_train_path, 'rb') as f:
        x_train_dict, y_train_dict = pickle.load(f)
        print('loaded training seperation')
else:
    x_train_dict = {}
    y_train_dict = {}
    for target_label in tqdm_notebook(range(10)):
        x_train_dict[target_label] = []
        y_train_dict[target_label] = []
        for i, label in enumerate(y_train):
            if list(label).index(1) == target_label:
                x_train_dict[target_label].append(x_train[i])
                y_train_dict[target_label].append(y_train[i])
    
    with open(separated_train_path, 'wb') as f:
        pickle.dump([x_train_dict, y_train_dict], f)
        print('saved training seperation')

if os.path.isfile(separated_test_path):
    with open(separated_test_path, 'rb') as f:
        x_test_dict, y_test_dict = pickle.load(f)
        print('loaded testing seperation')
else:
    x_test_dict = {}
    y_test_dict = {}
    for target_label in tqdm_notebook(range(10)):
        x_test_dict[target_label] = []
        y_test_dict[target_label] = []
        for i, label in enumerate(y_test):
            if list(label).index(1) == target_label:
                x_test_dict[target_label].append(x_test[i])
                y_test_dict[target_label].append(y_test[i])

    with open(separated_test_path, 'wb') as f:
        pickle.dump([x_test_dict, y_test_dict], f)
        print('saved testing seperation')
    
# convert dicts to lists
x_train_seperated = [np.array(x_train_dict[i]) for i in range(10)]
y_train_seperated = [np.array(y_train_dict[i]) for i in range(10)]

x_test_seperated = [np.array(x_test_dict[i]) for i in range(10)]
y_test_seperated = [np.array(y_test_dict[i]) for i in range(10)]
# Out:
# loaded training seperation
# loaded testing seperation

# %%
# summary of data shapes:
plt.figure()
plt.title('Data separation per class')
plt.bar(x_train_dict.keys(), [len(v) for v in x_train_dict.values()], color='tab:blue')
plt.bar(x_test_dict.keys(), [len(v) for v in x_test_dict.values()], color='orange', width=0.6)
plt.legend(['x_train', 'x_test'], loc='center right', framealpha=1.0)
plt.xlabel('class label')
plt.ylabel('count')
plt.show()

# %% [markdown]
# #### Separate the data into batches for clients to use

# %%
# Separate the data into a long list of batches, each batch representing a client training with that batch of images.
# After each batch, a new client will have the opportunity to train their batch of images.
# Batches are shuffled to simulate many clients training the model at once.

client_counts = {}
batch_sizes = {}
x_batches = []
y_batches = []

def ceil(a,b):
    return -(-a//b)

for class_idx in range(len(x_train_seperated)):
    # Get batches from class data:
    n_samples_per_class = len(x_train_seperated[class_idx])
    samples_per_client = n_samples_per_class / clients_per_class
    better_batch_size = int(math.ceil(samples_per_client))

    count = 0
    for i in range(ceil(n_samples_per_class, better_batch_size)):
        x_batches.append((class_idx, x_train_seperated[class_idx][i * better_batch_size: (i+1) * better_batch_size]))
        y_batches.append((class_idx, y_train_seperated[class_idx][i * better_batch_size: (i+1) * better_batch_size]))
        count += 1
    client_counts[class_idx] = count
    batch_sizes[class_idx] = better_batch_size
        
# double check that the clients_per_class is upheld per class
# (blue bars should be uniform, orange should change according to class):
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel('class label')
ax1.set_ylabel('client count', color=color)
plt.bar(client_counts.keys(), [v for v in client_counts.values()], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'orange'
ax2.set_ylabel('batch size', color=color)  # we already handled the x-label with ax1
plt.bar(batch_sizes.keys(), [v for v in batch_sizes.values()], color=color, width=0.6)
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, np.mean([v for v in batch_sizes.values()])*2)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

print('Clients per class:  {} ~= {}'.format(np.mean([v for v in client_counts.values()]), clients_per_class))
print('Total number of clients: {}'.format(np.sum([v for v in client_counts.values()])))
print('Average batch size: {}'.format(np.mean([v for v in batch_sizes.values()])))

split_batch_size = np.floor(np.mean([v for v in batch_sizes.values()]))
# Out:
# Clients per class:  99.6 ~= 100
# Total number of clients: 996
# Average batch size: 60.6

# %% [markdown]
# #### Batch and shuffle automatically

# %%
# Batch and shuffle the data for GAN
gan_train_dataset = tf.data.Dataset.from_tensor_slices(x_train).shuffle(BUFFER_SIZE).batch(gan_batch_size)

# %%
# Batch and shuffle the data for Split Learning
split_train_dataset = (x_batches, y_batches)
split_test_dataset = (x_test, y_test)

# %% [markdown]
# ## Build Model

# %%
# FUNCTIONAL versions of the graphs. When calling them, you will need to specify input_layer= and training=

def start_piece_(input_shape, filters=4):
    assert filters >= 1
    
    model = tf.keras.Sequential()
    model.add(Conv2D(filters, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
    
    return model

def blackbox_piece_(model, depth=1, filters=4):
    assert depth >= 1
    assert filters >= 1
    
    # for now, we will just give the black-box all the CNN layers
    for i in range(depth-1):
        model.add(Conv2D(filters, kernel_size=(3, 3), activation='relu', padding='same'))
    
    return model

def approximator_piece_(model, depth=1, filters=4):
    assert depth >= 1
    assert filters >= 1
    
    # for now, we will just give the approximator_piece piece the same complexity as bb (since we have shown it doens't matter)
    model = blackbox_piece_(model, depth, filters)
    
    return model

def end_piece_(model, dense_breadth=128, num_classes=10):
    assert dense_breadth >= num_classes
    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(dense_breadth, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %% [markdown]
# ## Graph Creation

# %%
class SplitLearning:
    
    def __init__(self, input_shape, depth, filters, dense, minibatch_size, batches_per_train_step, num_classes=10,
                 eval_batch_size=256):
        self.input_shape = input_shape
        self.depth = depth
        self.filters = filters
        self.dense = dense
        self.minibatch_size = minibatch_size
        self.num_classes = num_classes
        self.eval_batch_size = eval_batch_size
        self.iteration = 0
        
        self.batches_per_train_step = batches_per_train_step
        
        # make FUNCTIONAL versions of the graphs. When calling them, you will need to specify input_layer= and training=
        self.model = self.split_model(input_shape, depth, filters, dense)
        
        # define loss function
        self.cross_entropy = keras.losses.CategoricalCrossentropy(from_logits=True)
        
        # define optimizers
        self.optimizer = tf.keras.optimizers.Adam(1e-4)
        
        # define metrics
        self.acc_train_avg = None
        self.loss_train_avg = None
        
        # setup checkpointing
        self.ckpt = None
        self.init_ckpt()
        self.manager = None
        self.internal_iteration = None
        self.iteration_offset = 0
        
        # setup ops
        self.setup_ops()
        
    ###########################################################################################
    # Black-box model
        
    def split_model(self, input_shape, depth=1, filters=4, dense_breadth=128):
        assert depth >= 1
        assert filters >= 1
        assert dense_breadth >= self.num_classes

        model = start_piece_(input_shape, filters)
        model = blackbox_piece_(model, depth, filters)
        model = end_piece_(model, dense_breadth, self.num_classes)

        return model
    
    def model_loss(self, y_true, y_pred):
        return self.cross_entropy(y_true, y_pred)
        
    ###########################################################################################
    # Train
    
    def setup_ops(self):
        # INSPIRED BY: https://stackoverflow.com/questions/42156957/how-to-update-model-parameters-with-accumulated-gradients
        # https://www.tensorflow.org/tutorials/customization/custom_training_walkthrough
        
        self.tvs = self.model.trainable_variables
        self.accum_vars = [tf.Variable(tf.zeros_like(tv.initialized_value()), trainable=False) for tv in self.tvs]
        self.accum_counter = tf.Variable(0.0, trainable=False)
    
    def train(self, dataset, iteration):
        # setup checkpointing
        self.setup_ckpt(iteration)
        
        # initialize the metrics each new epoch
        if self.acc_train_avg is not None:
            del self.acc_train_avg
        if self.loss_train_avg is not None:
            del self.loss_train_avg
        self.acc_train_avg = tf.keras.metrics.Accuracy()
        self.loss_train_avg = tf.keras.metrics.Mean()
        
        x_batches, y_batches = dataset
        pbar = tqdm_notebook(total=len(x_batches))
        
        batch_idxs = list(range(len(x_batches)))
        if shuffle_clients:
            # shuffle the batches each time
            random.shuffle(batch_idxs)
            
        for i, batch_idx in enumerate(batch_idxs):
            x_batch = x_batches[batch_idx][1]
            y_batch = y_batches[batch_idx][1]
            
            self.train_step(i, x_batch, y_batch, len(batch_idxs) - 1)
            pbar.update(1)
            pbar.set_description('train_acc={:.2f}%'.format(self.acc_train_avg.result()*100))
        pbar.close()
        
        # save checkpoints
        self.checkpoint()
        
    def train_step(self, i, x_batch, y_batch, limit):
        # Iterate over the client's batch in minibatches:
        j = 0
        while(j < len(x_batch)):
            if self.minibatch_size is None:
                # use whole batch (no minibatch)
                x_minibatch = x_batch
                y_minibatch = y_batch
            else:
                x_minibatch = x_batch[j:(j+self.minibatch_size)]
                y_minibatch = y_batch[j:(j+self.minibatch_size)]

            # run the gradients
            loss_value, grads = self.grad(x_minibatch, y_minibatch)

            # accumulate them
            self.accumulate_grads(grads)

            if self.minibatch_size is None:
                break
            else:
                j += self.minibatch_size

        # perform a train step every batches_per_train_step number of batches:
        if (i > 0 and i % self.batches_per_train_step == 0) or i == limit:
            # Run the train_step ops to update the weights based on our accumulated gradients
            self.optimize()
            self.zero_out()
    
    def grad(self, inputs, targets):
        with tf.GradientTape() as tape:
            logits = self.model(inputs, training=True)
            loss_value = self.model_loss(targets, logits)
            
        # evaluate accuracy and append acc and loss to arrays
        self.acc_train_avg(tf.argmax(targets, 1), tf.argmax(logits, 1))
        self.loss_train_avg(loss_value)
        
        return loss_value, tape.gradient(loss_value, self.model.trainable_variables)
    
    def accumulate_grads(self, grads):
        # add to accum_vars the new gradients
        self.accum_vars = [self.accum_vars[i].assign_add(grad) for i, grad in enumerate(grads)]
        # increment the counter by 1
        self.accum_counter.assign_add(1.0)
        
    def optimize(self):
        # apply the gradients in accum_vars, dividing by the number in accum_counter
        self.optimizer.apply_gradients(
            [(accum_var / self.accum_counter, tv) \
                for (accum_var, tv) in zip(self.accum_vars, self.model.trainable_variables)]
        )
    
    def zero_out(self):
        # reset accum_vars and accum_counter back to 0
        self.accum_vars = [tv.assign(tf.zeros_like(tv)) for tv in self.accum_vars]
        self.accum_counter = tf.Variable(0.0, trainable=False)
        
    ###########################################################################################
    # Checkpoint
    
    def init_ckpt(self):
        self.ckpt = tf.train.Checkpoint(optimizer=self.optimizer, model=self.model)
        
    def setup_ckpt(self, iteration):
        # setup fresh checkpointer every new iteration
        if self.internal_iteration is None or iteration != self.internal_iteration - self.iteration_offset:
            ckpt_save_folder = os.path.join('checkpoints', 'it_{}'.format(iteration + self.iteration_offset), blackbox_checkpoint_folder)
            os.makedirs(ckpt_save_folder, exist_ok=True)
        
            if self.ckpt is not None:
                del self.ckpt
            if self.manager is not None:
                del self.manager

            self.ckpt = tf.train.Checkpoint(optimizer=self.optimizer, model=self.model)
            self.manager = tf.train.CheckpointManager(self.ckpt, ckpt_save_folder, max_to_keep=1)
            self.internal_iteration = iteration + self.iteration_offset
    
    def checkpoint(self):
        save_path = self.manager.save()
        print("Saved checkpoint: {}".format(save_path))
        
    def restore(self, it_restore=None, load_default=False):
        parent_folder = os.path.join('checkpoints')
        if it_restore is None and not load_default:
            # find the most recent iteration and checkpoint
            largest_it = None
            for d in glob(os.path.join(parent_folder, '*')):
                if os.path.isfile(os.path.join(d, blackbox_checkpoint_folder, 'checkpoint')):
                    # passed, valid checkpoint
                    it = int(d.split('_')[1])
                    if largest_it is None or it > largest_it:
                        largest_it = it
            if largest_it is not None:
                checkpoint_directory = os.path.join(parent_folder, 'it_{}'.format(largest_it), blackbox_checkpoint_folder)
                self.ckpt.restore(tf.train.latest_checkpoint(checkpoint_directory))
                self.iteration_offset = largest_it
                print('Restored latest checkpoint from {}'.format(checkpoint_directory))
            else:
                print('No weights found, starting with a fresh network')
        else:
            if load_default:
                checkpoint_directory = os.path.join(parent_folder, 'default', blackbox_checkpoint_folder)
            else:
                checkpoint_directory = os.path.join(parent_folder, 'it_{}'.format(it_restore), blackbox_checkpoint_folder)
            if os.path.isfile(os.path.join(checkpoint_directory, 'checkpoint')):
                self.ckpt.restore(tf.train.latest_checkpoint(checkpoint_directory))
                if it_restore is not None:
                    self.iteration_offset = it_restore
                print('Restored latest checkpoint from {}'.format(checkpoint_directory))
            else:
                print('No weights found at: {}'.format(checkpoint_directory))
        
    ###########################################################################################
    # Evaluate
        
    def evaluate(self, dataset):
        
        x, y = dataset
        
        acc_test_avg = tf.keras.metrics.Accuracy()
        loss_test_avg = tf.keras.metrics.Mean()
        for i in range(0, len(x), self.eval_batch_size):
            # get batch
            x_batch = x[i:i+self.eval_batch_size]
            y_batch = y[i:i+self.eval_batch_size]
            
            # evaluate
            logits = self.model(x_batch, training=False)
            acc_test_avg(tf.argmax(y_batch, 1), tf.argmax(logits, 1))
            loss_test_avg(self.model_loss(y_batch, logits))
        
        if self.acc_train_avg is not None and self.loss_train_avg is not None:
            print('Train Accuracy: {:.3f} | Loss: {:.3f}'.format(self.acc_train_avg.result(), self.loss_train_avg.result()))
        print('Test Accuracy: {:.3f} | Loss: {:.3f}'.format(acc_test_avg.result(), loss_test_avg.result()))
        print()

# %%
class GAN:
    
    def __init__(self, input_shape, depth, filters, dense, batch_size, noise_dim=100, num_classes=10,
                 discriminator=None):
        self.input_shape = input_shape
        self.depth = depth
        self.filters = filters
        self.dense = dense
        self.noise_dim = noise_dim
        self.batch_size = batch_size
        self.num_classes = num_classes
#         self.attack_class = attack_class # the label index of the (unknown) class that we want to predict
        self.save_ckpts = True
        
        # make FUNCTIONAL versions of the graphs. When calling them, you will need to specify input_layer= and training=
        if discriminator is not None:
            self.discriminator = discriminator
        else:
            self.discriminator = self.discriminator_model(input_shape, depth, filters, dense)
        self.generator = self.generator_model(noise_dim)
        
        self.cat_cross_entropy = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
        self.bin_cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        
        # define optimizers
        self.generator_optimizer = tf.keras.optimizers.Adam(1e-4)
        self.discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)
        
        # define metrics
        self.gen_loss_train_avg = None
        self.gen_acc_train_avg = None
        self.disc_loss_train_avg = None
        
        # seed for image generation
        self.num_examples_to_generate = 16
        self.seed = tf.random.normal([self.num_examples_to_generate, self.noise_dim])
        
        # labels for image generation
        label_pattern = [i % (self.num_classes) for i in range(self.num_examples_to_generate)]
        self.eval_labels = tf.one_hot(label_pattern, self.num_classes, dtype=tf.dtypes.float32)
        
        # setup metrics (TODO)
        
        # setup checkpointing
        self.discriminator_ckpt = None
        self.discriminator_manager = None
        self.generator_ckpt = None
        self.generator_manager = None
        self.internal_iteration = None
        self.iteration_offset = 0
        self.init_ckpts()
        
    ###########################################################################################
    # Label matching
        
    def soft_onehot(self, softmax, my_power=8):
        soft_extreme = softmax ** my_power
        norm = tf.reduce_sum(soft_extreme, axis=-1)
        almost_onehot = tf.math.divide(soft_extreme, tf.reshape(norm, (-1, 1)))
        return almost_onehot
        
#     def matches_label(self, fake_output, loop_times=3):
#         '''
#         Only works if the Discriminator is already trained on real images!!
#         1. Performs a softmax -> onehot conversion (differentiable approx.)
#         2. Multiplies this by the onehot version of the onehot attack label
#         3. Sums to reduce dimension
        
#         - if the sum is close to 1, the nn thinks that the image is a part of the attack class
#         - if the sum is close to 0, the nn thinks that the image is not of the attack class
#         - the sum should not be in between, due to the onehot conversion we perform in step 1
#         '''
#         # 1.
#         my_power = 8
#         for i in range(loop_times):
#             fake_output = self.soft_onehot(fake_output)
        
#         # 2.
#         attack_indices = tf.one_hot(self.attack_class, self.num_classes, dtype=tf.dtypes.float32)
#         matches = tf.math.multiply(fake_output, attack_indices)
        
#         # 3.
#         reduced = tf.math.reduce_sum(matches, axis=-1)
        
#         return reduced
        
    def matches_labels(self, fake_output, labels, loop_times=3):
        '''
        Only works if the Discriminator is already trained on real images!!
        1. Performs a softmax -> onehot conversion (differentiable approx.)
        2. Multiplies this by the onehot version of the onehot attack label
        3. Sums to reduce dimension
        
        - if the sum is close to 1, the nn thinks that the image is a part of the attack class
        - if the sum is close to 0, the nn thinks that the image is not of the attack class
        - the sum should not be in between, due to the onehot conversion we perform in step 1
        '''
        # 1.
        my_power = 8
        for i in range(loop_times):
            fake_output = self.soft_onehot(fake_output)
        
        # 2.
        matches = tf.math.multiply(fake_output, labels)
        
        # 3.
        reduced = tf.math.reduce_sum(matches, axis=-1)
        
        return reduced
        
#     def matches_label_simple(self, fake_output, loop_times=3):
#         '''
#         Simpler match, performs no softmax -> onehot conversion
#         - if the sum is close to 1, the nn thinks that the image is a part of the attack class
#         - if the sum is close to 0, the nn thinks that the image is not of the attack class
#         - the sum can be between 0 and 1, depending upon the certainty of the nn
#         '''
#         # get softmax probs at attack_class index
#         attack_indices = tf.one_hot(self.attack_class, self.num_classes, dtype=tf.dtypes.float32)
#         matches = tf.math.multiply(fake_output, attack_indices)
        
#         # sum to reduce (extract the softmax prob)
#         reduced = tf.math.reduce_sum(matches, axis=-1)
        
#         return reduced
        
    ###########################################################################################
    # Discriminator
    # - since we know the label
    
    def discriminator_model(self, input_shape, depth=1, filters=4, dense_breadth=128):
        assert depth >= 1
        assert filters >= 1
        assert dense_breadth >= self.num_classes

        model = start_piece_(input_shape, filters)
        model = approximator_piece_(model, depth, filters)
        model = end_piece_(model, dense_breadth, self.num_classes)

        return model
    
#     def discriminator_loss(self, fake_discrimination):
#         matches = self.matches_label(fake_discrimination, loop_times=10)
#         # we want the discriminator to NOT be fooled by these fake images
#         cross_entropy = self.cross_entropy(tf.zeros_like(matches), matches)
#         return cross_entropy
    
    def discriminator_loss(self, fake_discrimination, labels):
        matches = self.matches_labels(fake_discrimination, labels, loop_times=0)
        # we want the discriminator to NOT be fooled by these fake images
#         print(matches)
#         print(tf.zeros_like(matches))
        cross_entropy = self.bin_cross_entropy(tf.zeros_like(matches), matches)
#         print(cross_entropy)
#         print()
        return cross_entropy
    
    def discriminator_entropy(self, y_true, y_pred):
        return self.cat_cross_entropy(y_true, y_pred)
        
    ###########################################################################################
    # Generator

#     def generator_model(self, noise_dim=100):
#         model = tf.keras.Sequential()
        
#         model.add(Dense(7*7*256, use_bias=False, input_shape=(noise_dim,)))
#         model.add(BatchNormalization())
#         model.add(LeakyReLU())
#         model.add(Reshape((7, 7, 256)))

#         model.add(Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
#         model.add(BatchNormalization())
#         model.add(LeakyReLU())

#         model.add(Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
#         model.add(BatchNormalization())
#         model.add(LeakyReLU())

#         model.add(Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))

#         return model

    def generator_model(self, noise_dim=100):
        ACTIVATION = keras.layers.Activation("tanh")
        
        # Prepare noise input
        input_z = keras.layers.Input((noise_dim,))
        dense_z_1 = keras.layers.Dense(1024)(input_z)
        act_z_1 = ACTIVATION(dense_z_1)
        dense_z_2 = keras.layers.Dense(128 * 7 * 7)(act_z_1)
        bn_z_1 = keras.layers.BatchNormalization()(dense_z_2)
        reshape_z = keras.layers.Reshape((7, 7, 128), input_shape=(128 * 7 * 7,))(bn_z_1)

        # Prepare Conditional (label) input
        input_c = keras.layers.Input((self.num_classes,))
        dense_c_1 = keras.layers.Dense(1024)(input_c)
        act_c_1 = ACTIVATION(dense_c_1)
        dense_c_2 = keras.layers.Dense(128 * 7 * 7)(act_c_1)
        bn_c_1 = keras.layers.BatchNormalization()(dense_c_2)
        reshape_c = keras.layers.Reshape((7, 7, 128), input_shape=(128 * 7 * 7,))(bn_c_1)

        # Combine input source
        concat_z_c = keras.layers.Concatenate()([reshape_z, reshape_c])

        # Image generation with the concatenated inputs
        up_1 = keras.layers.UpSampling2D(size=(2, 2))(concat_z_c)
        conv_1 = keras.layers.Conv2D(64, (5, 5), padding='same')(up_1)
        act_1 = ACTIVATION(conv_1)
        up_2 = keras.layers.UpSampling2D(size=(2, 2))(act_1)
        conv_2 = keras.layers.Conv2D(1, (5, 5), padding='same')(up_2)
        act_2 = keras.layers.Activation("tanh")(conv_2)
        model = keras.models.Model(inputs=[input_z, input_c], outputs=act_2)
        return model
    
#     def generator_loss(self, fake_discrimination):
#         matches = self.matches_label_simple(fake_discrimination)
#         # we want the discriminator to be fooled by these fake images
#         cross_entropy = self.cross_entropy(tf.ones_like(matches), matches)
#         return cross_entropy

#     def generator_loss(self, fake_discrimination):
#         # make a list of onehot vectors representing the attack class:
#         attack_label = tf.one_hot(self.attack_class, self.num_classes, dtype=tf.dtypes.float32)
        
#         # tile into the right dims (https://stackoverflow.com/questions/45315545/replicate-a-row-tensor-using-tf-tile)
#         vec = attack_label
#         multiply = tf.constant([self.batch_size])
#         attack_batch = tf.reshape(tf.tile(vec, multiply), [ multiply[0], tf.shape(vec)[0]])
        
#         # we want the discriminator to be fooled by these fake images
#         cross_entropy = self.cross_entropy(fake_discrimination, attack_batch)
#         return cross_entropy

    def generator_loss(self, fake_discrimination, labels):
        # we want the discriminator to be fooled by these fake images
        cross_entropy = self.cat_cross_entropy(fake_discrimination, labels)
        return cross_entropy
        
    ###########################################################################################
    # Trainer
        
    def train(self, iteration):
        # setup checkpointing
        self.setup_ckpts(iteration)
        
        # initialize the metrics each new epoch
        if self.gen_acc_train_avg is not None:
            del self.gen_acc_train_avg
        if self.gen_loss_train_avg is not None:
            del self.gen_loss_train_avg
        if self.disc_loss_train_avg is not None:
            del self.disc_loss_train_avg
        
        self.gen_loss_train_avg = tf.keras.metrics.Mean()
        self.gen_acc_train_avg = tf.keras.metrics.Accuracy()
        self.disc_loss_train_avg = tf.keras.metrics.Mean()
        
        pbar = tqdm_notebook(total=200) # why is this governed by dataset still?
        
        for i in range(200):
            self.train_step(train_discriminator=(self.gen_acc_train_avg.result() >= 0.95),
                            train_generator=(self.gen_acc_train_avg.result() < 0.95))
            pbar.update(1)
            pbar.set_description('g_acc={:.2f}, g_loss={:.2f}, d_loss={:.2f}'.format(self.gen_acc_train_avg.result(),
                                                                                     self.gen_loss_train_avg.result(),
                                                                                     self.disc_loss_train_avg.result()))
        
        # save checkpoints
        self.checkpoint()
    
    def train_step(self, train_discriminator, train_generator):
        noise = tf.random.normal([self.batch_size, self.noise_dim])
        random_classes = tf.random.uniform(shape=(self.batch_size, ), maxval=self.num_classes, dtype=tf.dtypes.int32)
        labels = tf.one_hot(random_classes, self.num_classes, dtype=tf.dtypes.float32)

        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            generated_images = self.generator([noise, labels], training=True)
            
            # convert the [-1 1] image into [0 1] (due to tanh activation)
            generated_images = 0.5 * generated_images + 0.5

            # we don't evaluate any real images in our case
            #real_output = self.discriminator(images, training=True)
            
            fake_discrimination = self.discriminator(generated_images, training=True)

            gen_loss = self.generator_loss(fake_discrimination, labels)
            disc_loss = self.discriminator_loss(fake_discrimination, labels)
            
            # evaluate accuracy and append acc and loss to arrays
            self.gen_loss_train_avg(gen_loss)
            self.gen_acc_train_avg(tf.argmax(labels, 1), tf.argmax(fake_discrimination, 1))
            self.disc_loss_train_avg(disc_loss)

        gradients_of_generator = gen_tape.gradient(gen_loss, self.generator.trainable_variables)
        gradients_of_discriminator = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)

        if train_generator:
            self.generator_optimizer.apply_gradients(zip(gradients_of_generator, self.generator.trainable_variables))
        if train_discriminator:
            self.discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, self.discriminator.trainable_variables))
        
    ###########################################################################################
    # Checkpoint
    
    def init_ckpts(self):
        self.discriminator_ckpt = tf.train.Checkpoint(optimizer=self.discriminator_optimizer, model=self.discriminator)
        self.generator_ckpt = tf.train.Checkpoint(optimizer=self.generator_optimizer, model=self.generator)
    
    def setup_ckpts(self, iteration):
        if self.save_ckpts:
            # setup fresh checkpointer every new iteration
            if self.internal_iteration is None or (self.internal_iteration != (iteration + self.iteration_offset)):
                self.setup_discriminator_ckpt(iteration + self.iteration_offset)
                self.setup_generator_ckpt(iteration + self.iteration_offset)
                self.internal_iteration = iteration + self.iteration_offset
        
    def setup_discriminator_ckpt(self, iteration):
        ckpt_save_folder = os.path.join('checkpoints', 'it_{}'.format(iteration), discriminator_checkpoint_folder)
        os.makedirs(ckpt_save_folder, exist_ok=True)

        if self.discriminator_ckpt is not None:
            del self.discriminator_ckpt
        if self.discriminator_manager is not None:
            del self.discriminator_manager

        self.discriminator_ckpt = tf.train.Checkpoint(optimizer=self.discriminator_optimizer, model=self.discriminator)
        self.discriminator_manager = tf.train.CheckpointManager(self.discriminator_ckpt, ckpt_save_folder, max_to_keep=1)
        
    def setup_generator_ckpt(self, iteration):
        ckpt_save_folder = os.path.join('checkpoints', 'it_{}'.format(iteration), generator_checkpoint_folder)
        os.makedirs(ckpt_save_folder, exist_ok=True)

        if self.generator_ckpt is not None:
            del self.generator_ckpt
        if self.generator_manager is not None:
            del self.generator_manager

        self.generator_ckpt = tf.train.Checkpoint(optimizer=self.generator_optimizer, model=self.generator)
        self.generator_manager = tf.train.CheckpointManager(self.generator_ckpt, ckpt_save_folder, max_to_keep=1)
    
    def checkpoint(self):
        if self.save_ckpts:
            self.checkpoint_discriminator()
            self.checkpoint_generator()
        
    def checkpoint_discriminator(self):
        save_path = self.discriminator_manager.save()
        print("Saved D checkpoint: {}".format(save_path))
        
    def checkpoint_generator(self):
        save_path = self.generator_manager.save()
        print("Saved G checkpoint: {}".format(save_path))
        
    def restore(self, it_restore=None, load_default=False):
        self.restore_discriminator(it_restore, load_default)
        tmp_offset = copy(self.iteration_offset)
        self.restore_generator(it_restore, load_default)
        assert tmp_offset == self.iteration_offset
        
    def restore_discriminator(self, it_restore=None, load_default=False):
        parent_folder = os.path.join('checkpoints')
        if it_restore is None and not load_default:
            # find the most recent iteration and checkpoint
            largest_it = None
            for d in glob(os.path.join(parent_folder, '*')):
                if os.path.isfile(os.path.join(d, discriminator_checkpoint_folder, 'checkpoint')):
                    # passed, valid checkpoint
                    it = int(d.split('_')[1])
                    if largest_it is None or it > largest_it:
                        largest_it = it
            if largest_it is not None:
                checkpoint_directory = os.path.join(parent_folder, 'it_{}'.format(largest_it), discriminator_checkpoint_folder)
                self.discriminator_ckpt.restore(tf.train.latest_checkpoint(checkpoint_directory))
                self.iteration_offset = largest_it
                print('Restored D to latest checkpoint from {}'.format(checkpoint_directory))
            else:
                print('No weights found for D, starting with a fresh network')
        else:
            if load_default:
                checkpoint_directory = os.path.join(parent_folder, 'default', discriminator_checkpoint_folder)
            else:
                checkpoint_directory = os.path.join(parent_folder, 'it_{}'.format(it_restore), discriminator_checkpoint_folder)
            if os.path.isfile(os.path.join(checkpoint_directory, 'checkpoint')):
                self.discriminator_ckpt.restore(tf.train.latest_checkpoint(checkpoint_directory))
                if it_restore is not None:
                    self.iteration_offset = it_restore
                print('Restored D to latest checkpoint from {}'.format(checkpoint_directory))
            else:
                print('No weights found at: {}'.format(checkpoint_directory))
        
    def restore_generator(self, it_restore=None, load_default=False):
        parent_folder = os.path.join('checkpoints')
        if it_restore is None and not load_default:
            # find the most recent iteration and checkpoint
            largest_it = None
            for d in glob(os.path.join(parent_folder, '*')):
                if os.path.isfile(os.path.join(d, generator_checkpoint_folder, 'checkpoint')):
                    # passed, valid checkpoint
                    it = int(d.split('_')[1])
                    if largest_it is None or it > largest_it:
                        largest_it = it
            if largest_it is not None:
                checkpoint_directory = os.path.join(parent_folder, 'it_{}'.format(largest_it), generator_checkpoint_folder)
                self.generator_ckpt.restore(tf.train.latest_checkpoint(checkpoint_directory))
                self.iteration_offset = largest_it
                print('Restored G to latest checkpoint from {}'.format(checkpoint_directory))
            else:
                print('No weights found for G, starting with a fresh network')
        else:
            if load_default:
                checkpoint_directory = os.path.join(parent_folder, 'default', generator_checkpoint_folder)
            else:
                checkpoint_directory = os.path.join(parent_folder, 'it_{}'.format(it_restore), generator_checkpoint_folder)
            if os.path.isfile(os.path.join(checkpoint_directory, 'checkpoint')):
                self.generator_ckpt.restore(tf.train.latest_checkpoint(checkpoint_directory))
                if it_restore is not None:
                    self.iteration_offset = it_restore
                print('Restored G to latest checkpoint from {}'.format(checkpoint_directory))
            else:
                print('No weights found at: {}'.format(checkpoint_directory))
        
    ###########################################################################################
    # Evaluate
            
    def generate_images(self):
        # Notice `training` is set to False.
        # This is so all layers run in inference mode (batchnorm).
        
        # make the number of 
        
        predictions = self.generator([self.seed, self.eval_labels], training=False)
        predictions = 0.5 * predictions + 0.5

        fig = plt.figure(figsize=(4,4))

        for i in range(predictions.shape[0]):
            plt.subplot(4, 4, i+1)
            plt.imshow(predictions[i, :, :, 0] * 255.0, cmap='gray')
            plt.axis('off')

        plt.show()
        
    def evaluate_gan(self, dataset):
        
        if self.gen_acc_train_avg is not None:
            print('G Train Acc:     {:.3f} | Loss: {:.3f}'.format(self.gen_acc_train_avg.result(),
                                                                self.gen_loss_train_avg.result()))
            print('D Train Acc:     NaN   | Loss: {:.3f}'.format(self.disc_loss_train_avg.result()))
        disc_acc_test = self.evaluate_discriminator(dataset)
        return disc_acc_test
        
    def evaluate_discriminator(self, dataset):
        
        x, y = dataset
        
        acc_test_avg = tf.keras.metrics.Accuracy()
        loss_test_avg = tf.keras.metrics.Mean()
        for i in range(0, len(x), self.batch_size):
            # get batch
            x_batch = x[i:i+self.batch_size]
            y_batch = y[i:i+self.batch_size]
            
            # evaluate
            logits = self.discriminator(x_batch, training=False)
            acc_test_avg(tf.argmax(y_batch, 1), tf.argmax(logits, 1))
            loss_test_avg(self.discriminator_entropy(y_batch, logits))
            
        print('D Test Accuracy: {:.3f} | Loss: {:.3f}'.format(acc_test_avg.result(), loss_test_avg.result()))
        print()
        
        return acc_test_avg.result()

# %%
class SplitLearningGAN:
    
    def __init__(self, input_shape, split_train_dataset, split_test_dataset,
                 depth, filters, dense,
                 noise_dim, gan_batch_size, gan_epochs,
                 split_minibatch_size, split_batches_per_train_step, split_epochs, split_num_classes, split_eval_batch_size,
                 use_blackbox=True):
        self.input_shape = input_shape
        self.depth = depth
        self.filters = filters
        self.dense = dense
        self.noise_dim = noise_dim
        
        self.gan_batch_size = gan_batch_size
        self.gan_epochs = gan_epochs
        
        self.split_minibatch_size = split_minibatch_size
        self.split_batches_per_train_step = split_batches_per_train_step
        self.split_epochs = split_epochs
        self.split_train_dataset = split_train_dataset
        self.split_test_dataset = split_test_dataset
        self.split_num_classes = split_num_classes
        self.split_eval_batch_size = split_eval_batch_size
        
        # create the Split Learning Trainer
        self.split = SplitLearning(self.input_shape, self.depth, self.filters, self.dense, self.split_minibatch_size, 
                                   self.split_batches_per_train_step, self.split_num_classes, self.split_eval_batch_size)
        
        if use_blackbox:
            # treat the Split Learning NN as a Black-box
            self.gan = GAN(self.input_shape, self.depth, self.filters, self.dense, self.gan_batch_size,
                           self.noise_dim, self.split_num_classes)
        else:
            # use the Split Learning NN as the GAN's Discriminator as an easy check:
            self.gan = GAN(self.input_shape, self.depth, self.filters, self.dense, self.gan_batch_size,
                           self.noise_dim, self.split_num_classes, discriminator=self.split.model)
        
    def query_blackbox(self):
        '''
        Send images generated by the GAN into the Split Learning model (TODO)
        '''
        pass
        
    def train_system(self):
        
        iteration = 1
        
        # Train the Split Learning model for 25 epochs:
#         print('~'*40)
#         print('Training Split Learning')
#         for e in tqdm_notebook(range(self.split_epochs)):
#             if e == 0:
#                 print('~'*40)
#             self.split.train(self.split_train_dataset, iteration)
#             self.split.evaluate(self.split_test_dataset)
            
        if not EASY_MODE:
            # Refine the Discriminator in the GAN, since Split Learning is a Black-box:
            print('~'*40)
            print('Refining Discriminator')
            print('~'*40)
            # TODO
        
        # Train the GAN for X epochs, and see if the generator can produce anything:
        print('~'*40)
        print('Training GAN')
        for e in tqdm_notebook(range(self.gan_epochs)):
            if e == 0:
                print('~'*40)
            self.gan.train(self.gan_train_dataset, iteration)
            self.gan.generate_images()
            
    def train_gan(self, original_disc_acc, reset_d_every_epoch=False):
        
        iteration = 1
        
        # Train the GAN for X epochs, and see if the generator can produce anything:
        print('~'*40)
        print('Training GAN')
        for e in tqdm_notebook(range(self.gan_epochs)):
            if e == 0:
                print('~'*40)
            self.gan.train(iteration)
            self.gan.generate_images()
            
            disc_acc_test = self.gan.evaluate_gan(self.split_test_dataset)
            
            if reset_d_every_epoch or disc_acc_test < original_disc_acc * 0.8:
                # reset D back to the original weights, so as not to diverge D too much over training time
                self.gan.restore_discriminator(load_default=True)
                self.gan.evaluate_discriminator(self.split_test_dataset)

# %%
# Iterate over all attack classes to see if we can estimate all classes from D!

def test_GAN():
    print('='*40)
    print('Training GAN for attacking ANY class:')
    print('='*40)

    slg = SplitLearningGAN(input_shape, split_train_dataset, split_test_dataset,
                           best_depth, best_filters, best_dense, 
                           noise_dim, gan_batch_size, gan_epochs,
                           split_minibatch_size, split_batches_per_train_step, split_epochs, split_num_classes, split_eval_batch_size,
                           use_blackbox=False)

    # load pretrained weights if they exist:
    slg.split.restore(load_default=True, it_restore=1)
    slg.gan.restore(load_default=True, it_restore=1)
#     slg.gan.save_ckpts = False # don't save the training ckpts for this test

    # This SHOULD have the restored weights from split
    print()
    print('Double checking that the D in the GAN has been trained:')
    original_disc_acc = slg.gan.evaluate_discriminator(slg.split_test_dataset)
    print()

    slg.train_gan(original_disc_acc=original_disc_acc, reset_d_every_epoch=False)
    
    del slg

# %%
test_GAN()
# Out:
# ========================================
# Training GAN for attacking ANY class:
# ========================================
# Restored latest checkpoint from checkpoints\default\blackbox_checkpoint
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# Restored G to latest checkpoint from checkpoints\default\generator_checkpoint
#
# Double checking that the D in the GAN has been trained:
# D Test Accuracy: 0.762 | Loss: 1.695
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training GAN
# HBox(children=(IntProgress(value=0, max=150), HTML(value='')))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-1
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-1
# G Train Acc:     1.000 | Loss: 1.461
# D Train Acc:     NaN   | Loss: 1.313
# D Test Accuracy: 0.735 | Loss: 1.720
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-2
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-2
# G Train Acc:     0.781 | Loss: 1.680
# D Train Acc:     NaN   | Loss: 1.177
# D Test Accuracy: 0.105 | Loss: 2.356
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-3
# G Train Acc:     0.903 | Loss: 1.558
# D Train Acc:     NaN   | Loss: 1.253
# D Test Accuracy: 0.297 | Loss: 2.159
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-4
# G Train Acc:     0.867 | Loss: 1.594
# D Train Acc:     NaN   | Loss: 1.231
# D Test Accuracy: 0.650 | Loss: 1.809
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-28
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-5
# G Train Acc:     0.821 | Loss: 1.640
# D Train Acc:     NaN   | Loss: 1.202
# D Test Accuracy: 0.151 | Loss: 2.308
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-6
# G Train Acc:     0.898 | Loss: 1.563
# D Train Acc:     NaN   | Loss: 1.250
# D Test Accuracy: 0.288 | Loss: 2.167
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-7
# G Train Acc:     0.672 | Loss: 1.789
# D Train Acc:     NaN   | Loss: 1.109
# D Test Accuracy: 0.099 | Loss: 2.361
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-8
# G Train Acc:     0.942 | Loss: 1.520
# D Train Acc:     NaN   | Loss: 1.276
# D Test Accuracy: 0.403 | Loss: 2.052
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-9
# G Train Acc:     0.816 | Loss: 1.646
# D Train Acc:     NaN   | Loss: 1.198
# D Test Accuracy: 0.110 | Loss: 2.350
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-10
# G Train Acc:     0.912 | Loss: 1.549
# D Train Acc:     NaN   | Loss: 1.259
# D Test Accuracy: 0.488 | Loss: 1.965
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-11
# G Train Acc:     0.702 | Loss: 1.759
# D Train Acc:     NaN   | Loss: 1.128
# D Test Accuracy: 0.254 | Loss: 2.203
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-12
# G Train Acc:     0.898 | Loss: 1.563
# D Train Acc:     NaN   | Loss: 1.250
# D Test Accuracy: 0.465 | Loss: 1.991
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-13
# G Train Acc:     0.928 | Loss: 1.533
# D Train Acc:     NaN   | Loss: 1.268
# D Test Accuracy: 0.348 | Loss: 2.107
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-14
# G Train Acc:     0.999 | Loss: 1.463
# D Train Acc:     NaN   | Loss: 1.312
# D Test Accuracy: 0.888 | Loss: 1.575
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-28
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-15
# G Train Acc:     0.926 | Loss: 1.536
# D Train Acc:     NaN   | Loss: 1.267
# D Test Accuracy: 0.796 | Loss: 1.666
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-29
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-16
# G Train Acc:     0.942 | Loss: 1.520
# D Train Acc:     NaN   | Loss: 1.276
# D Test Accuracy: 0.588 | Loss: 1.868
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-17
# G Train Acc:     0.642 | Loss: 1.819
# D Train Acc:     NaN   | Loss: 1.091
# D Test Accuracy: 0.142 | Loss: 2.316
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-18
# G Train Acc:     0.902 | Loss: 1.559
# D Train Acc:     NaN   | Loss: 1.252
# D Test Accuracy: 0.122 | Loss: 2.337
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-19
# G Train Acc:     0.877 | Loss: 1.584
# D Train Acc:     NaN   | Loss: 1.237
# D Test Accuracy: 0.396 | Loss: 2.059
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-20
# G Train Acc:     0.919 | Loss: 1.542
# D Train Acc:     NaN   | Loss: 1.263
# D Test Accuracy: 0.872 | Loss: 1.588
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-28
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-21
# G Train Acc:     0.900 | Loss: 1.562
# D Train Acc:     NaN   | Loss: 1.251
# D Test Accuracy: 0.872 | Loss: 1.588
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-29
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-22
# G Train Acc:     0.900 | Loss: 1.561
# D Train Acc:     NaN   | Loss: 1.251
# D Test Accuracy: 0.872 | Loss: 1.588
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-30
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-23
# G Train Acc:     0.907 | Loss: 1.554
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.872 | Loss: 1.588
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-31
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-24
# G Train Acc:     0.912 | Loss: 1.550
# D Train Acc:     NaN   | Loss: 1.258
# D Test Accuracy: 0.718 | Loss: 1.744
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-32
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-25
# G Train Acc:     0.763 | Loss: 1.699
# D Train Acc:     NaN   | Loss: 1.165
# D Test Accuracy: 0.373 | Loss: 2.080
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-26
# G Train Acc:     0.863 | Loss: 1.599
# D Train Acc:     NaN   | Loss: 1.227
# D Test Accuracy: 0.251 | Loss: 2.206
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-27
# G Train Acc:     0.778 | Loss: 1.683
# D Train Acc:     NaN   | Loss: 1.175
# D Test Accuracy: 0.272 | Loss: 2.186
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-28
# G Train Acc:     0.894 | Loss: 1.568
# D Train Acc:     NaN   | Loss: 1.247
# D Test Accuracy: 0.239 | Loss: 2.216
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-29
# G Train Acc:     0.904 | Loss: 1.558
# D Train Acc:     NaN   | Loss: 1.253
# D Test Accuracy: 0.147 | Loss: 2.305
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-30
# G Train Acc:     0.915 | Loss: 1.547
# D Train Acc:     NaN   | Loss: 1.260
# D Test Accuracy: 0.244 | Loss: 2.210
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-31
# G Train Acc:     0.914 | Loss: 1.548
# D Train Acc:     NaN   | Loss: 1.260
# D Test Accuracy: 0.263 | Loss: 2.190
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-32
# G Train Acc:     0.913 | Loss: 1.549
# D Train Acc:     NaN   | Loss: 1.259
# D Test Accuracy: 0.252 | Loss: 2.203
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-33
# G Train Acc:     0.916 | Loss: 1.545
# D Train Acc:     NaN   | Loss: 1.261
# D Test Accuracy: 0.291 | Loss: 2.159
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-34
# G Train Acc:     0.921 | Loss: 1.540
# D Train Acc:     NaN   | Loss: 1.264
# D Test Accuracy: 0.322 | Loss: 2.128
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-35
# G Train Acc:     0.914 | Loss: 1.547
# D Train Acc:     NaN   | Loss: 1.260
# D Test Accuracy: 0.276 | Loss: 2.175
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-36
# G Train Acc:     0.651 | Loss: 1.810
# D Train Acc:     NaN   | Loss: 1.096
# D Test Accuracy: 0.089 | Loss: 2.371
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-37
# G Train Acc:     0.797 | Loss: 1.665
# D Train Acc:     NaN   | Loss: 1.187
# D Test Accuracy: 0.179 | Loss: 2.278
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-38
# G Train Acc:     0.893 | Loss: 1.569
# D Train Acc:     NaN   | Loss: 1.246
# D Test Accuracy: 0.264 | Loss: 2.192
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-39
# G Train Acc:     0.888 | Loss: 1.573
# D Train Acc:     NaN   | Loss: 1.243
# D Test Accuracy: 0.455 | Loss: 2.003
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-40
# G Train Acc:     0.543 | Loss: 1.918
# D Train Acc:     NaN   | Loss: 1.030
# D Test Accuracy: 0.103 | Loss: 2.357
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-41
# G Train Acc:     0.906 | Loss: 1.555
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.381 | Loss: 2.076
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-42
# G Train Acc:     0.751 | Loss: 1.711
# D Train Acc:     NaN   | Loss: 1.158
# D Test Accuracy: 0.120 | Loss: 2.338
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-43
# G Train Acc:     0.833 | Loss: 1.628
# D Train Acc:     NaN   | Loss: 1.209
# D Test Accuracy: 0.228 | Loss: 2.229
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-44
# G Train Acc:     0.542 | Loss: 1.919
# D Train Acc:     NaN   | Loss: 1.029
# D Test Accuracy: 0.098 | Loss: 2.362
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-45
# G Train Acc:     0.937 | Loss: 1.525
# D Train Acc:     NaN   | Loss: 1.273
# D Test Accuracy: 0.370 | Loss: 2.081
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-46
# G Train Acc:     0.915 | Loss: 1.546
# D Train Acc:     NaN   | Loss: 1.260
# D Test Accuracy: 0.537 | Loss: 1.918
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-47
# G Train Acc:     0.774 | Loss: 1.687
# D Train Acc:     NaN   | Loss: 1.173
# D Test Accuracy: 0.110 | Loss: 2.351
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-48
# G Train Acc:     0.910 | Loss: 1.551
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.405 | Loss: 2.046
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-49
# G Train Acc:     0.806 | Loss: 1.655
# D Train Acc:     NaN   | Loss: 1.193
# D Test Accuracy: 0.301 | Loss: 2.154
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-50
# G Train Acc:     0.846 | Loss: 1.615
# D Train Acc:     NaN   | Loss: 1.218
# D Test Accuracy: 0.345 | Loss: 2.109
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-51
# G Train Acc:     0.895 | Loss: 1.566
# D Train Acc:     NaN   | Loss: 1.248
# D Test Accuracy: 0.359 | Loss: 2.097
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-52
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.292 | Loss: 2.166
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-53
# G Train Acc:     0.904 | Loss: 1.557
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.328 | Loss: 2.128
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-54
# G Train Acc:     0.907 | Loss: 1.554
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.308 | Loss: 2.149
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-55
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.323 | Loss: 2.132
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-56
# G Train Acc:     0.903 | Loss: 1.558
# D Train Acc:     NaN   | Loss: 1.253
# D Test Accuracy: 0.352 | Loss: 2.105
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-57
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.363 | Loss: 2.092
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-58
# G Train Acc:     0.899 | Loss: 1.562
# D Train Acc:     NaN   | Loss: 1.251
# D Test Accuracy: 0.246 | Loss: 2.213
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-59
# G Train Acc:     0.802 | Loss: 1.659
# D Train Acc:     NaN   | Loss: 1.190
# D Test Accuracy: 0.240 | Loss: 2.221
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-60
# G Train Acc:     0.935 | Loss: 1.526
# D Train Acc:     NaN   | Loss: 1.273
# D Test Accuracy: 0.460 | Loss: 1.995
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-61
# G Train Acc:     0.693 | Loss: 1.768
# D Train Acc:     NaN   | Loss: 1.123
# D Test Accuracy: 0.176 | Loss: 2.281
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-62
# G Train Acc:     0.880 | Loss: 1.582
# D Train Acc:     NaN   | Loss: 1.238
# D Test Accuracy: 0.229 | Loss: 2.225
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-63
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.271 | Loss: 2.187
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-64
# G Train Acc:     0.909 | Loss: 1.552
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.380 | Loss: 2.075
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-65
# G Train Acc:     0.912 | Loss: 1.549
# D Train Acc:     NaN   | Loss: 1.259
# D Test Accuracy: 0.347 | Loss: 2.107
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-66
# G Train Acc:     0.910 | Loss: 1.551
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.325 | Loss: 2.131
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-67
# G Train Acc:     0.909 | Loss: 1.552
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.395 | Loss: 2.059
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-68
# G Train Acc:     0.912 | Loss: 1.549
# D Train Acc:     NaN   | Loss: 1.259
# D Test Accuracy: 0.429 | Loss: 2.024
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-69
# G Train Acc:     0.909 | Loss: 1.552
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.409 | Loss: 2.046
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-70
# G Train Acc:     0.908 | Loss: 1.553
# D Train Acc:     NaN   | Loss: 1.256
# D Test Accuracy: 0.469 | Loss: 1.983
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-71
# G Train Acc:     0.914 | Loss: 1.547
# D Train Acc:     NaN   | Loss: 1.260
# D Test Accuracy: 0.401 | Loss: 2.054
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-72
# G Train Acc:     0.922 | Loss: 1.539
# D Train Acc:     NaN   | Loss: 1.265
# D Test Accuracy: 0.390 | Loss: 2.064
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-73
# G Train Acc:     0.915 | Loss: 1.546
# D Train Acc:     NaN   | Loss: 1.260
# D Test Accuracy: 0.339 | Loss: 2.118
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-74
# G Train Acc:     0.866 | Loss: 1.595
# D Train Acc:     NaN   | Loss: 1.230
# D Test Accuracy: 0.245 | Loss: 2.213
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-75
# G Train Acc:     0.849 | Loss: 1.613
# D Train Acc:     NaN   | Loss: 1.219
# D Test Accuracy: 0.112 | Loss: 2.350
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-76
# G Train Acc:     0.826 | Loss: 1.635
# D Train Acc:     NaN   | Loss: 1.205
# D Test Accuracy: 0.589 | Loss: 1.866
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-77
# G Train Acc:     0.870 | Loss: 1.592
# D Train Acc:     NaN   | Loss: 1.232
# D Test Accuracy: 0.446 | Loss: 2.009
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-78
# G Train Acc:     0.830 | Loss: 1.631
# D Train Acc:     NaN   | Loss: 1.208
# D Test Accuracy: 0.245 | Loss: 2.212
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-79
# G Train Acc:     0.882 | Loss: 1.579
# D Train Acc:     NaN   | Loss: 1.240
# D Test Accuracy: 0.309 | Loss: 2.149
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-80
# G Train Acc:     0.885 | Loss: 1.577
# D Train Acc:     NaN   | Loss: 1.242
# D Test Accuracy: 0.336 | Loss: 2.120
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-81
# G Train Acc:     0.908 | Loss: 1.553
# D Train Acc:     NaN   | Loss: 1.256
# D Test Accuracy: 0.364 | Loss: 2.089
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-82
# G Train Acc:     0.913 | Loss: 1.549
# D Train Acc:     NaN   | Loss: 1.259
# D Test Accuracy: 0.287 | Loss: 2.170
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-83
# G Train Acc:     0.908 | Loss: 1.553
# D Train Acc:     NaN   | Loss: 1.256
# D Test Accuracy: 0.386 | Loss: 2.067
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-84
# G Train Acc:     0.907 | Loss: 1.554
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.338 | Loss: 2.118
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-85
# G Train Acc:     0.909 | Loss: 1.552
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.377 | Loss: 2.075
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-86
# G Train Acc:     0.909 | Loss: 1.552
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.398 | Loss: 2.055
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-87
# G Train Acc:     0.842 | Loss: 1.619
# D Train Acc:     NaN   | Loss: 1.215
# D Test Accuracy: 0.199 | Loss: 2.260
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-88
# G Train Acc:     0.905 | Loss: 1.557
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.251 | Loss: 2.206
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-89
# G Train Acc:     0.908 | Loss: 1.553
# D Train Acc:     NaN   | Loss: 1.256
# D Test Accuracy: 0.466 | Loss: 1.988
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-90
# G Train Acc:     0.906 | Loss: 1.555
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.432 | Loss: 2.021
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-91
# G Train Acc:     0.872 | Loss: 1.589
# D Train Acc:     NaN   | Loss: 1.234
# D Test Accuracy: 0.253 | Loss: 2.204
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-92
# G Train Acc:     0.837 | Loss: 1.625
# D Train Acc:     NaN   | Loss: 1.212
# D Test Accuracy: 0.357 | Loss: 2.101
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-93
# G Train Acc:     0.907 | Loss: 1.554
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.282 | Loss: 2.175
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-94
# G Train Acc:     0.878 | Loss: 1.583
# D Train Acc:     NaN   | Loss: 1.237
# D Test Accuracy: 0.486 | Loss: 1.967
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-95
# G Train Acc:     0.836 | Loss: 1.625
# D Train Acc:     NaN   | Loss: 1.212
# D Test Accuracy: 0.236 | Loss: 2.222
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-96
# G Train Acc:     0.909 | Loss: 1.552
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.354 | Loss: 2.099
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-97
# G Train Acc:     0.908 | Loss: 1.553
# D Train Acc:     NaN   | Loss: 1.256
# D Test Accuracy: 0.480 | Loss: 1.972
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-98
# G Train Acc:     0.902 | Loss: 1.559
# D Train Acc:     NaN   | Loss: 1.252
# D Test Accuracy: 0.320 | Loss: 2.137
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-99
# G Train Acc:     0.907 | Loss: 1.554
# D Train Acc:     NaN   | Loss: 1.256
# D Test Accuracy: 0.310 | Loss: 2.147
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-100
# G Train Acc:     0.907 | Loss: 1.554
# D Train Acc:     NaN   | Loss: 1.256
# D Test Accuracy: 0.339 | Loss: 2.117
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-101
# G Train Acc:     0.855 | Loss: 1.607
# D Train Acc:     NaN   | Loss: 1.223
# D Test Accuracy: 0.385 | Loss: 2.073
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-102
# G Train Acc:     0.917 | Loss: 1.544
# D Train Acc:     NaN   | Loss: 1.262
# D Test Accuracy: 0.573 | Loss: 1.882
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-103
# G Train Acc:     0.858 | Loss: 1.603
# D Train Acc:     NaN   | Loss: 1.225
# D Test Accuracy: 0.336 | Loss: 2.120
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-104
# G Train Acc:     0.875 | Loss: 1.586
# D Train Acc:     NaN   | Loss: 1.236
# D Test Accuracy: 0.369 | Loss: 2.089
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-105
# G Train Acc:     0.841 | Loss: 1.620
# D Train Acc:     NaN   | Loss: 1.215
# D Test Accuracy: 0.243 | Loss: 2.215
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-106
# G Train Acc:     0.844 | Loss: 1.617
# D Train Acc:     NaN   | Loss: 1.216
# D Test Accuracy: 0.182 | Loss: 2.278
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-107
# G Train Acc:     0.915 | Loss: 1.546
# D Train Acc:     NaN   | Loss: 1.261
# D Test Accuracy: 0.348 | Loss: 2.108
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-108
# G Train Acc:     0.899 | Loss: 1.563
# D Train Acc:     NaN   | Loss: 1.250
# D Test Accuracy: 0.373 | Loss: 2.083
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-109
# G Train Acc:     0.910 | Loss: 1.551
# D Train Acc:     NaN   | Loss: 1.258
# D Test Accuracy: 0.442 | Loss: 2.012
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-110
# G Train Acc:     0.912 | Loss: 1.549
# D Train Acc:     NaN   | Loss: 1.259
# D Test Accuracy: 0.410 | Loss: 2.043
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-111
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.470 | Loss: 1.983
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-112
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.290 | Loss: 2.168
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-113
# G Train Acc:     0.906 | Loss: 1.555
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.352 | Loss: 2.104
#
# ...
# D Train Acc:     NaN   | Loss: 1.226
# D Test Accuracy: 0.388 | Loss: 2.069
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-116
# G Train Acc:     0.850 | Loss: 1.612
# D Train Acc:     NaN   | Loss: 1.220
# D Test Accuracy: 0.332 | Loss: 2.125
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-117
# G Train Acc:     0.929 | Loss: 1.532
# D Train Acc:     NaN   | Loss: 1.269
# D Test Accuracy: 0.929 | Loss: 1.531
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-28
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-118
# G Train Acc:     0.669 | Loss: 1.792
# D Train Acc:     NaN   | Loss: 1.108
# D Test Accuracy: 0.224 | Loss: 2.235
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-119
# G Train Acc:     0.911 | Loss: 1.551
# D Train Acc:     NaN   | Loss: 1.258
# D Test Accuracy: 0.294 | Loss: 2.163
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-120
# G Train Acc:     0.911 | Loss: 1.550
# D Train Acc:     NaN   | Loss: 1.258
# D Test Accuracy: 0.426 | Loss: 2.024
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-121
# G Train Acc:     0.787 | Loss: 1.675
# D Train Acc:     NaN   | Loss: 1.181
# D Test Accuracy: 0.101 | Loss: 2.359
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-122
# G Train Acc:     0.786 | Loss: 1.676
# D Train Acc:     NaN   | Loss: 1.180
# D Test Accuracy: 0.098 | Loss: 2.362
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-123
# G Train Acc:     0.899 | Loss: 1.562
# D Train Acc:     NaN   | Loss: 1.251
# D Test Accuracy: 0.375 | Loss: 2.078
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-124
# G Train Acc:     0.901 | Loss: 1.560
# D Train Acc:     NaN   | Loss: 1.252
# D Test Accuracy: 0.361 | Loss: 2.093
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-125
# G Train Acc:     0.904 | Loss: 1.557
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.261 | Loss: 2.196
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-126
# G Train Acc:     0.902 | Loss: 1.559
# D Train Acc:     NaN   | Loss: 1.252
# D Test Accuracy: 0.374 | Loss: 2.080
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-127
# G Train Acc:     0.905 | Loss: 1.557
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.278 | Loss: 2.179
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-128
# G Train Acc:     0.903 | Loss: 1.558
# D Train Acc:     NaN   | Loss: 1.253
# D Test Accuracy: 0.278 | Loss: 2.179
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-129
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.255 | Loss: 2.203
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-130
# G Train Acc:     0.904 | Loss: 1.557
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.278 | Loss: 2.179
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-131
# G Train Acc:     0.903 | Loss: 1.558
# D Train Acc:     NaN   | Loss: 1.253
# D Test Accuracy: 0.246 | Loss: 2.211
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-132
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.300 | Loss: 2.156
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-133
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.321 | Loss: 2.133
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-134
# G Train Acc:     0.903 | Loss: 1.558
# D Train Acc:     NaN   | Loss: 1.253
# D Test Accuracy: 0.293 | Loss: 2.161
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-135
# G Train Acc:     0.910 | Loss: 1.551
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.272 | Loss: 2.185
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-136
# G Train Acc:     0.906 | Loss: 1.555
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.317 | Loss: 2.139
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-137
# G Train Acc:     0.906 | Loss: 1.555
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.258 | Loss: 2.200
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-138
# G Train Acc:     0.908 | Loss: 1.554
# D Train Acc:     NaN   | Loss: 1.256
# D Test Accuracy: 0.233 | Loss: 2.223
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-139
# G Train Acc:     0.912 | Loss: 1.549
# D Train Acc:     NaN   | Loss: 1.258
# D Test Accuracy: 0.246 | Loss: 2.211
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-140
# G Train Acc:     0.692 | Loss: 1.769
# D Train Acc:     NaN   | Loss: 1.122
# D Test Accuracy: 0.112 | Loss: 2.348
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-141
# G Train Acc:     0.778 | Loss: 1.683
# D Train Acc:     NaN   | Loss: 1.175
# D Test Accuracy: 0.208 | Loss: 2.250
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-142
# G Train Acc:     0.766 | Loss: 1.695
# D Train Acc:     NaN   | Loss: 1.168
# D Test Accuracy: 0.103 | Loss: 2.357
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-143
# G Train Acc:     0.897 | Loss: 1.564
# D Train Acc:     NaN   | Loss: 1.250
# D Test Accuracy: 0.255 | Loss: 2.202
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-144
# G Train Acc:     0.751 | Loss: 1.710
# D Train Acc:     NaN   | Loss: 1.159
# D Test Accuracy: 0.210 | Loss: 2.248
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-145
# G Train Acc:     0.833 | Loss: 1.628
# D Train Acc:     NaN   | Loss: 1.210
# D Test Accuracy: 0.231 | Loss: 2.230
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-146
# G Train Acc:     0.839 | Loss: 1.623
# D Train Acc:     NaN   | Loss: 1.213
# D Test Accuracy: 0.202 | Loss: 2.259
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-147
# G Train Acc:     0.905 | Loss: 1.556
# D Train Acc:     NaN   | Loss: 1.254
# D Test Accuracy: 0.223 | Loss: 2.236
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-148
# G Train Acc:     0.912 | Loss: 1.549
# D Train Acc:     NaN   | Loss: 1.259
# D Test Accuracy: 0.242 | Loss: 2.215
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-149
# G Train Acc:     0.909 | Loss: 1.552
# D Train Acc:     NaN   | Loss: 1.257
# D Test Accuracy: 0.243 | Loss: 2.214
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Saved D checkpoint: checkpoints\it_2\discriminator_checkpoint\ckpt-27
# Saved G checkpoint: checkpoints\it_2\generator_checkpoint\ckpt-150
# G Train Acc:     0.906 | Loss: 1.555
# D Train Acc:     NaN   | Loss: 1.255
# D Test Accuracy: 0.255 | Loss: 2.202
#
# Restored D to latest checkpoint from checkpoints\default\discriminator_checkpoint
# D Test Accuracy: 0.762 | Loss: 1.695
#
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
